# %%
import pandas as pd
import numpy as np

# %%
Rock = pd.read_csv('Rock.csv')
Country = pd.read_csv('Country.csv').drop(columns = ['Unnamed: 0','Song'])
Rap = pd.read_csv('Rap.csv')

# %%
Rock
# Out:
#       Artist Genre                                             Lyrics
# 0      AC/DC  Rock  Back in black, I hit the sack I've been too lo...
# 1      AC/DC  Rock  Oi! Oi! Oi! Oi! Oi! Oi! Oi! Oi! Oi! Oi! Oi! Oi...
# 2      AC/DC  Rock  Living easy, lovin' free Season ticket on a on...
# 3      AC/DC  Rock  Thunder, ah Thunder, ah Thunder, ah Thunder, a...
# 4      AC/DC  Rock  She was a fast machine, she kept her motor cle...
# ...      ...   ...                                                ...
# 3295  ZZ Top  Rock  Did you ever hear the story That happened not ...
# 3296  ZZ Top  Rock  Hello darling, surprised? Yes, it's me again I...
# 3297  ZZ Top  Rock  Now, I just got back from baby's We've been ro...
# 3298  ZZ Top  Rock  When I hear that Santa Fe start blowing I wond...
# 3299  ZZ Top  Rock  Rain fell this mornin', make me feel so bad On...
#
# [3300 rows x 3 columns]

# %%
Country
# Out:
#              Artist    Genre  \
# 0     Morgan Wallen  Country
# 1     Morgan Wallen  Country
# 2     Morgan Wallen  Country
# 3     Morgan Wallen  Country
# 4     Morgan Wallen  Country
# ...             ...      ...
# 1239   Justin Moore  Country
# 1240   Justin Moore  Country
# 1241   Justin Moore  Country
# 1242   Justin Moore  Country
# 1243   Justin Moore  Country
#
#                                                  Lyrics
# 0     Yeah, you used to talk about Getting even furt...
# 1     A 'Bama red 4Runner pulled into the party With...
# 2     (Lyrics From Snippet) I met her down at Aldean...
# 3     The way I talk, I guess I got it from my pops ...
# 4     It's Friday after 5, got here just in time Wen...
# ...                                                 ...
# 1239  That water tower's got the sun going down behi...
# 1240  You stood on that bank when I got baptized Gav...
# 1241  Got my phone on airplane mode You couldn't rea...
# ...

# %%
Rap
# Out:
#       Unnamed: 0          Artist Genre  \
# 0              0  Kendrick Lamar   Rap
# 1              1  Kendrick Lamar   Rap
# 2              2  Kendrick Lamar   Rap
# 3              3  Kendrick Lamar   Rap
# 4              4  Kendrick Lamar   Rap
# ...          ...             ...   ...
# 2645        2645        Cardi B.   Rap
# 2646        2646        Cardi B.   Rap
# 2647        2647        Cardi B.   Rap
# 2648        2648        Cardi B.   Rap
# 2649        2649        Cardi B.   Rap
#
#                                                  Lyrics
# 0     Nobody pray for me It been that day for me Way...
# 1     If Pirus and Crips all got along They'd probab...
# 2     Pour up (Drank), head shot (Drank) Sit down (D...
# 3     I got, I got, I got, I got— Loyalty, got royal...
# 4     Uh, me and my niggas tryna get it, ya bish (Ya...
# ...                                                 ...
# 2645  They out here looking for revenge All day, all...
# ...

# %%
lyrics = Rock.append(Country, ignore_index = True).append(Rap, ignore_index = True)
lyrics.to_csv('lyrics.csv', index = False)

# %%
lyrics.Genre.value_counts()
# Out:
# Rock       3300
# Rap        2650
# Country    1244
# Name: Genre, dtype: int64
